# %% [markdown]
# **Note:** We are using cocktail peanut fork and fixed dependences, updates should be manual.
#
# 🚱 Chek if you are running in T4 or better.
#
# For not is not suitable for T4, because of bfloat16 transformer, we need a lower version like float16

# %%
#@title Clone FramePack and enter the app directory
# !git clone https://github.com/cocktailpeanut/FramePack.git
# %cd FramePack
# Out:
# fatal: destination path 'FramePack' already exists and is not an empty directory.
# /content/FramePack

# %%
#@title Install Python packages
# !pip install \
    accelerate==1.6.0 \
    diffusers==0.33.1 \
    transformers==4.46.2 \
    gradio==5.23.0 \
    sentencepiece==0.2.0 \
    pillow==11.1.0 \
    av==12.1.0 \
    numpy==1.26.2 \
    scipy==1.12.0 \
    requests==2.31.0 \
    torchsde==0.2.6 \
    einops \
    xformers \
    opencv-contrib-python \
    safetensors
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 23.7 MB/s eta 0:00:00
# ...

# %%
#@title Run the Gradio demo with a public share link
# !python demo_gradio.py --share
# Out:
# 2025-04-20 15:00:56.696178: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745161256.918049   13184 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745161256.978160   13184 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-20 15:00:57.427839: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
